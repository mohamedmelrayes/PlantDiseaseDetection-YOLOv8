# %%
# !nvidia-smi
# Out:
# /bin/bash: nvidia-smi: command not found

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Y8x5l9ziFuFjdDtLVYtj")
project = rf.workspace("portsaid-university-da2b0").project("plants-detection-github")
dataset = project.version(1).download("yolov8")
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to plants-detection-github-1 in yolov8:: 100%|██████████| 7491/7491 [00:02<00:00, 2826.94it/s]

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=30 imgsz=800 plots=True
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content
# /bin/bash: yolo: command not found

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# ls: cannot access '{HOME}/runs/detect/train/': No such file or directory
